# %% [markdown]
# ## Transforming the Data Raw

# %%
import pandas as pd

# %%
dataRaw = pd.read_csv('../Data_Extract/Data_Raw/datahackers-survey-2019-anonymous-responses.csv')
display(dataRaw.head())
# Out:
#                        ('P0', 'id')  ('P1', 'age') ('P2', 'gender')  \
# 0  v9otv8j9wdvjrv9otvwnn9owhzq54ktv           37.0        Masculino
# 1  875ul998t0hqcv0871uptwf3oswcfv35           24.0         Feminino
# 2  puscuk079vw1pusbb900pzw2xvpxtgdk           26.0        Masculino
# 3  rmel8ewqpbffp2mnfbzermel8eqincov           21.0        Masculino
# 4  pj9mgud4d6mdct1l7vq0pj9mgu78h6ju           27.0        Masculino
#
#    ('P3', 'living_in_brasil') ('P5', 'living_state')  \
# 0                           1      Minas Gerais (MG)
# 1                           1         São Paulo (SP)
# 2                           1         São Paulo (SP)
# 3                           1         São Paulo (SP)
# 4                           1                    NaN
#
#    ('P6', 'born_or_graduated') ('P8', 'degreee_level')  \
# 0                          1.0  Estudante de Graduação
# 1                          1.0  Estudante de Graduação
# 2                          1.0   Graduação/Bacharelado
# ...

# %% [markdown]
# # To Do:
#
# I won't drop the identifier 'P1' because it has many columns, and if I drop it, it will be hard to locate the columns later.
#
# I need Clean and Transform

# %%
dataRaw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1765 entries, 0 to 1764
# Columns: 170 entries, ('P0', 'id') to ('D6', 'anonymized_role')
# dtypes: float64(5), int64(146), object(19)
# memory usage: 2.3+ MB

# %%
display(dataRaw.describe())
# Out:
#        ('P1', 'age')  ('P3', 'living_in_brasil')  ('P6', 'born_or_graduated')  \
# count    1741.000000                 1765.000000                  1731.000000
# mean       29.800689                    0.980737                     0.810514
# std         6.595795                    0.137488                     0.392007
# min        18.000000                    0.000000                     0.000000
# 25%        25.000000                    1.000000                     1.000000
# 50%        29.000000                    1.000000                     1.000000
# 75%        34.000000                    1.000000                     1.000000
# max        50.000000                    1.000000                     1.000000
#
#        ('P13', 'manager')  ('P19', 'is_data_science_professional')  \
# count         1527.000000                              1765.000000
# mean             0.199738                                 0.518414
# ...

# %%
dataRaw.isnull().sum()
# Out:
# ('P0', 'id')                             0
# ('P1', 'age')                           24
# ('P2', 'gender')                         3
# ('P3', 'living_in_brasil')               0
# ('P5', 'living_state')                 337
#                                       ...
# ('D2', 'origin_macroregion')          1440
# ('D3', 'anonymized_degree_area')        35
# ('D4', 'anonymized_market_sector')     243
# ('D5', 'anonymized_manager_level')    1460
# ('D6', 'anonymized_role')              514
# Length: 170, dtype: int64

# %%
dataRaw
# Out:
#                           ('P0', 'id')  ('P1', 'age') ('P2', 'gender')  \
# 0     v9otv8j9wdvjrv9otvwnn9owhzq54ktv           37.0        Masculino
# 1     875ul998t0hqcv0871uptwf3oswcfv35           24.0         Feminino
# 2     puscuk079vw1pusbb900pzw2xvpxtgdk           26.0        Masculino
# 3     rmel8ewqpbffp2mnfbzermel8eqincov           21.0        Masculino
# 4     pj9mgud4d6mdct1l7vq0pj9mgu78h6ju           27.0        Masculino
# ...                                ...            ...              ...
# 1760  qkjyuc8dayrrqahyjqkj841kpgymnpau           23.0         Feminino
# 1761  7z5vvw7ycrxn4sujnv7z5vvw7r36gi5k           39.0        Masculino
# 1762  0s2jaountv3tyrae0sir4jd8o5hz19ob           36.0        Masculino
# 1763  r3kvh535z7xai2v8er3kv791tkmcysz8           29.0        Masculino
# 1764  1cz0hm5i92rw913f1cz0hmvferfavkkb           22.0              NaN
#
#       ('P3', 'living_in_brasil') ('P5', 'living_state')  \
# 0                              1      Minas Gerais (MG)
# ...

# %%
# Dropando Col

dataRaw = dataRaw.drop(columns="('P6', 'born_or_graduated')")

# %% [markdown]
# ## The Data is Transformed

# %%
dataRaw
# Out:
#                           ('P0', 'id')  ('P1', 'age') ('P2', 'gender')  \
# 0     v9otv8j9wdvjrv9otvwnn9owhzq54ktv           37.0        Masculino
# 1     875ul998t0hqcv0871uptwf3oswcfv35           24.0         Feminino
# 2     puscuk079vw1pusbb900pzw2xvpxtgdk           26.0        Masculino
# 3     rmel8ewqpbffp2mnfbzermel8eqincov           21.0        Masculino
# 4     pj9mgud4d6mdct1l7vq0pj9mgu78h6ju           27.0        Masculino
# ...                                ...            ...              ...
# 1760  qkjyuc8dayrrqahyjqkj841kpgymnpau           23.0         Feminino
# 1761  7z5vvw7ycrxn4sujnv7z5vvw7r36gi5k           39.0        Masculino
# 1762  0s2jaountv3tyrae0sir4jd8o5hz19ob           36.0        Masculino
# 1763  r3kvh535z7xai2v8er3kv791tkmcysz8           29.0        Masculino
# 1764  1cz0hm5i92rw913f1cz0hmvferfavkkb           22.0              NaN
#
#       ('P3', 'living_in_brasil') ('P5', 'living_state')  \
# 0                              1      Minas Gerais (MG)
# ...

# %%
dataRaw.to_json(
    r'C:\Users\joaoh\Desktop\Ciencia_Dados\Projetos\Python--ETL--Start\Data_Transform\Data_Processed\dataHackers.json',
    orient='records',
    indent=4
)

# %%
dataRaw.to_csv(
    r'C:\Users\joaoh\Desktop\Ciencia_Dados\Projetos\Python--ETL--Start\Data_Transform\Data_Processed\dataHackers.csv',
    index=False
)
